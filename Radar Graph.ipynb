# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from radar_graph import *

# %%
variables = ('Requirements', 'Management', 'Design', 'Development', 'Testing', 'UA', 'Implementation')

data = (1, .8, .5, .6, 1.1, 1.2, 1.0)
ranges = [(0.1, 1.45)] * len(variables)   

#plotting
fig1 = plt.figure(figsize=(6,6))
radar = RadarGraph(fig1, variables, ranges, 4, 'SPI per Area (should be 1)')

radar.plot(data, color = 'black')
radar.fill(data, color = 'black', alpha=0.9)
radar.circles([1.45,0.80,0.60],['green', 'yellow', 'red'], alpha=0.5)
plt.show()
